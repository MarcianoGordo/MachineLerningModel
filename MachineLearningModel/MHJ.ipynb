# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split as tt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import ExtraTreesRegressor

# %%
data = pd.read_csv('C:/Users/joaoa/Documents/Projects/machine/Obesity Classification.csv')
data
# Out:
#       ID  Age  Gender  Height  Weight   BMI          Label
# 0      1   25    Male     175      80  25.3  Normal Weight
# 1      2   30  Female     160      60  22.5  Normal Weight
# 2      3   35    Male     180      90  27.3     Overweight
# 3      4   40  Female     150      50  20.0    Underweight
# 4      5   45    Male     190     100  31.2          Obese
# ..   ...  ...     ...     ...     ...   ...            ...
# 103  106   11    Male     175      10   3.9    Underweight
# 104  107   16  Female     160      10   3.9    Underweight
# 105  108   21    Male     180      15   5.6    Underweight
# 106  109   26  Female     150      15   5.6    Underweight
# 107  110   31    Male     190      20   8.3    Underweight
#
# [108 rows x 7 columns]

# %%
data ['Label'] = data['Label'].replace('Normal Weight',0)

# %%
data ['Label'] = data['Label'].replace('Overweight',1)

# %%
data ['Label'] = data['Label'].replace('Underweight',2)

# %%
data ['Label'] = data['Label'].replace('Obese',3)
# Out:
# C:\Users\joaoa\AppData\Local\Temp\ipykernel_19492\1711323992.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data ['Label'] = data['Label'].replace('Obese',3)

# %%
data ['Gender'] = data['Gender'].replace('Male',22)

# %%
data ['Gender'] = data['Gender'].replace('Female',11)
# Out:
# C:\Users\joaoa\AppData\Local\Temp\ipykernel_19492\2355638318.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data ['Gender'] = data['Gender'].replace('Female',11)

# %%
y = data['Label']
x = data.drop('Label', axis = 1)
x
# Out:
#       ID  Age  Gender  Height  Weight   BMI
# 0      1   25      22     175      80  25.3
# 1      2   30      11     160      60  22.5
# 2      3   35      22     180      90  27.3
# 3      4   40      11     150      50  20.0
# 4      5   45      22     190     100  31.2
# ..   ...  ...     ...     ...     ...   ...
# 103  106   11      22     175      10   3.9
# 104  107   16      11     160      10   3.9
# 105  108   21      22     180      15   5.6
# 106  109   26      11     150      15   5.6
# 107  110   31      22     190      20   8.3
#
# [108 rows x 6 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      2
# 4      3
#       ..
# 103    2
# 104    2
# 105    2
# 106    2
# 107    2
# Name: Label, Length: 108, dtype: int64

# %%
x_tr,x_ts,y_tr,y_ts = tt (x,y, test_size = 0.3)

# %%
x_tr
# Out:
#     ID  Age  Gender  Height  Weight   BMI
# 84  87   18      11     160      20   8.3
# 21  23   73      11     160      60  22.5
# 61  64   31      11     150      45  18.7
# 17  19   53      11     130      40  16.7
# 45  48   52      11     130      75  25.0
# ..  ..  ...     ...     ...     ...   ...
# 35  38   54      11     130      85  27.5
# 73  76   40      11     140      50  20.0
# 58  61   16      22     175      55  21.2
# 71  74   30      11     150      40  16.7
# 48  51   67      22     175      65  22.7
#
# [75 rows x 6 columns]

# %%
y_tr
# Out:
# 84    2
# 21    0
# 61    2
# 17    2
# 45    1
#      ..
# 35    1
# 73    2
# 58    0
# 71    2
# 48    0
# Name: Label, Length: 75, dtype: int64

# %%
x_ts.shape
# Out:
# (33, 6)

# %%
y_ts.shape
# Out:
# (33,)

# %%
cdata = ExtraTreesClassifier(n_estimators=100)
cdata.fit(x_tr, y_tr)
# Out:
# ExtraTreesClassifier()

# %%
ndata = cdata.score(x_ts,y_ts)
print("Resultado do aprendizado:", ndata)
# Out:
# Resultado do aprendizado: 0.9696969696969697

# %%
y_ts[1:100]
# Out:
# 27     2
# 96     2
# 46     3
# 39     2
# 30     0
# 82     0
# 18     3
# 59     2
# 70     0
# 69     2
# 29     0
# 23     2
# 103    2
# 60     0
# 100    2
# 42     1
# 0      0
# 53     0
# 41     0
# 26     3
# 104    2
# 68     2
# 65     0
# 47     1
# 99     2
# 77     0
# 76     1
# 75     0
# 88     2
# 55     1
# 83     2
# 92     2
# Name: Label, dtype: int64

# %%
x_ts[1:100]
# Out:
#       ID  Age  Gender  Height  Weight   BMI
# 27    29  103      11     130      30  13.3
# 96    99   27      11     150      20   8.3
# 46    49   57      22     210     105  28.9
# 39    42   22      11     160      45  18.7
# 30    32   24      11     160      55  21.2
# 82    85   34      22     190      55  21.2
# 18    20   58      22     210     110  34.2
# 59    62   21      11     160      35  16.7
# 70    73   25      22     180      55  21.2
# 69    72   20      11     160      30  13.3
# 29    31   19      22     175      75  24.2
# 23    25   83      11     150      50  20.0
# 103  106   11      22     175      10   3.9
# 60    63   26      22     180      65  22.7
# 100  103   47      11     130      30  13.3
# 42    45   37      22     190      85  26.1
# 0      1   25      22     175      80  25.3
# 53    56   92      11     140      65  22.7
# 41    44   32      11     150      55  21.2
# 26    28   98      22     200     110  34.2
# ...

# %%
guess = cdata.predict(x_ts[1:100])
guess
# Out:
# array([2, 2, 3, 2, 0, 0, 3, 2, 0, 2, 0, 2, 2, 0, 2, 1, 0, 0, 0, 3, 2, 2,
#        0, 1, 2, 1, 1, 0, 2, 1, 2, 2], dtype=int64)
